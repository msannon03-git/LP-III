# %%
# Import Libraries

import pandas as pd
import numpy as np
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

# %%
# Load Data
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')


print("Train dataset shape:", train.shape)
print("Test dataset shape:", test.shape)
# Out:
# Train dataset shape: (891, 12)
# Test dataset shape: (418, 11)

# %%
train.info()
train.head()

# Correlation heatmap (numeric columns only)
train_numeric = train.select_dtypes(include=['int64', 'float64'])
train_numeric.corr().style.background_gradient(cmap='BuGn')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# <style type="text/css">
# #T_33744_row0_col0, #T_33744_row1_col1, #T_33744_row2_col2, #T_33744_row3_col3, #T_33744_row4_col4, #T_33744_row5_col5, #T_33744_row6_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_33744_row0_col1 {
#   background-color: #cdece6;
#   color: #000000;
# }
# #T_33744_row0_col2 {
#   background-color: #acdfd4;
#   color: #000000;
# }
# #T_33744_row0_col3 {
#   background-color: #bae5dc;
#   color: #000000;
# }
# #T_33744_row0_col4, #T_33744_row3_col1 {
#   background-color: #d8f0ef;
#   color: #000000;
# }
# #T_33744_row0_col5 {
#   background-color: #dff3f4;
#   color: #000000;
# }
# #T_33744_row0_col6 {
#   background-color: #9fdacc;
#   color: #000000;
# }
# #T_33744_row1_col0, #T_33744_row5_col0 {
#   background-color: #f0f9fb;
#   color: #000000;
# }
# #T_33744_row1_col2 {
#   background-color: #e3f4f8;
#   color: #000000;
# }
# #T_33744_row1_col3, #T_33744_row1_col4 {
#   background-color: #d4efec;
#   color: #000000;
# }
# #T_33744_row1_col5 {
#   background-color: #d1eee9;
#   color: #000000;
# }
# #T_33744_row1_col6 {
#   background-color: #60bf9c;
#   color: #000000;
# }
# #T_33744_row2_col0 {
#   background-color: #f4fbfc;
#   color: #000000;
# }
# #T_33744_row2_col1, #T_33744_row2_col3, #T_33744_row2_col6, #T_33744_row3_col4, #T_33744_row3_col5, #T_33744_row4_col0, #T_33744_row6_col2 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_33744_row2_col4 {
#   background-color: #b8e4db;
#   color: #000000;
# }
# #T_33744_row2_col5 {
#   background-color: #dbf2f2;
#   color: #000000;
# }
# #T_33744_row3_col0 {
#   background-color: #ebf7fa;
#   color: #000000;
# }
# #T_33744_row3_col2 {
#   background-color: #e7f6f9;
#   color: #000000;
# }
# #T_33744_row3_col6 {
#   background-color: #88d1bd;
#   color: #000000;
# }
# #T_33744_row4_col1 {
#   background-color: #d1eeea;
#   color: #000000;
# }
# #T_33744_row4_col2 {
#   background-color: #8cd2bf;
#   color: #000000;
# }
# #T_33744_row4_col3 {
#   background-color: #f1fafc;
#   color: #000000;
# }
# #T_33744_row4_col5 {
#   background-color: #63c0a0;
#   color: #000000;
# }
# #T_33744_row4_col6 {
#   background-color: #77c9b0;
#   color: #000000;
# }
# #T_33744_row5_col1 {
#   background-color: #b2e2d7;
#   color: #000000;
# }
# #T_33744_row5_col2 {
#   background-color: #9ddacb;
#   color: #000000;
# }
# #T_33744_row5_col3 {
#   background-color: #e4f5f8;
#   color: #000000;
# }
# #T_33744_row5_col4 {
#   background-color: #56ba91;
#   color: #f1f1f1;
# }
# #T_33744_row5_col6 {
#   background-color: #68c3a6;
#   color: #000000;
# }
# #T_33744_row6_col0 {
#   background-color: #eef8fb;
#   color: #000000;
# }
# #T_33744_row6_col1 {
#   background-color: #7dccb5;
#   color: #000000;
# }
# #T_33744_row6_col3 {
#   background-color: #a8ded2;
#   color: #000000;
# }
# #T_33744_row6_col4 {
#   background-color: #a0dbcd;
#   color: #000000;
# }
# #T_33744_row6_col5 {
#   background-color: #a7ddd1;
#   color: #000000;
# }
# </style>
# <table id="T_33744" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_33744_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_33744_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_33744_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_33744_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_33744_level0_col4" class="col_heading level0 col4" >SibSp</th>
#       <th id="T_33744_level0_col5" class="col_heading level0 col5" >Parch</th>
#       <th id="T_33744_level0_col6" class="col_heading level0 col6" >Fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33744_level0_row0" class="row_heading level0 row0" >PassengerId</th>
#       <td id="T_33744_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_33744_row0_col1" class="data row0 col1" >-0.005007</td>
#       <td id="T_33744_row0_col2" class="data row0 col2" >-0.035144</td>
#       <td id="T_33744_row0_col3" class="data row0 col3" >0.036847</td>
#       <td id="T_33744_row0_col4" class="data row0 col4" >-0.057527</td>
#       <td id="T_33744_row0_col5" class="data row0 col5" >-0.001652</td>
#       <td id="T_33744_row0_col6" class="data row0 col6" >0.012658</td>
#     </tr>
#     <tr>
#       <th id="T_33744_level0_row1" class="row_heading level0 row1" >Survived</th>
#       <td id="T_33744_row1_col0" class="data row1 col0" >-0.005007</td>
#       <td id="T_33744_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_33744_row1_col2" class="data row1 col2" >-0.338481</td>
#       <td id="T_33744_row1_col3" class="data row1 col3" >-0.077221</td>
#       <td id="T_33744_row1_col4" class="data row1 col4" >-0.035322</td>
#       <td id="T_33744_row1_col5" class="data row1 col5" >0.081629</td>
#       <td id="T_33744_row1_col6" class="data row1 col6" >0.257307</td>
#     </tr>
#     <tr>
#       <th id="T_33744_level0_row2" class="row_heading level0 row2" >Pclass</th>
#       <td id="T_33744_row2_col0" class="data row2 col0" >-0.035144</td>
#       <td id="T_33744_row2_col1" class="data row2 col1" >-0.338481</td>
#       <td id="T_33744_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_33744_row2_col3" class="data row2 col3" >-0.369226</td>
#       <td id="T_33744_row2_col4" class="data row2 col4" >0.083081</td>
#       <td id="T_33744_row2_col5" class="data row2 col5" >0.018443</td>
#       <td id="T_33744_row2_col6" class="data row2 col6" >-0.549500</td>
#     </tr>
#     <tr>
#       <th id="T_33744_level0_row3" class="row_heading level0 row3" >Age</th>
#       <td id="T_33744_row3_col0" class="data row3 col0" >0.036847</td>
#       <td id="T_33744_row3_col1" class="data row3 col1" >-0.077221</td>
#       <td id="T_33744_row3_col2" class="data row3 col2" >-0.369226</td>
#       <td id="T_33744_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_33744_row3_col4" class="data row3 col4" >-0.308247</td>
#       <td id="T_33744_row3_col5" class="data row3 col5" >-0.189119</td>
#       <td id="T_33744_row3_col6" class="data row3 col6" >0.096067</td>
#     </tr>
#     <tr>
#       <th id="T_33744_level0_row4" class="row_heading level0 row4" >SibSp</th>
#       <td id="T_33744_row4_col0" class="data row4 col0" >-0.057527</td>
#       <td id="T_33744_row4_col1" class="data row4 col1" >-0.035322</td>
#       <td id="T_33744_row4_col2" class="data row4 col2" >0.083081</td>
#       <td id="T_33744_row4_col3" class="data row4 col3" >-0.308247</td>
#       <td id="T_33744_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_33744_row4_col5" class="data row4 col5" >0.414838</td>
#       <td id="T_33744_row4_col6" class="data row4 col6" >0.159651</td>
#     </tr>
#     <tr>
#       <th id="T_33744_level0_row5" class="row_heading level0 row5" >Parch</th>
#       <td id="T_33744_row5_col0" class="data row5 col0" >-0.001652</td>
#       <td id="T_33744_row5_col1" class="data row5 col1" >0.081629</td>
#       <td id="T_33744_row5_col2" class="data row5 col2" >0.018443</td>
#       <td id="T_33744_row5_col3" class="data row5 col3" >-0.189119</td>
#       <td id="T_33744_row5_col4" class="data row5 col4" >0.414838</td>
#       <td id="T_33744_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_33744_row5_col6" class="data row5 col6" >0.216225</td>
#     </tr>
#     <tr>
#       <th id="T_33744_level0_row6" class="row_heading level0 row6" >Fare</th>
#       <td id="T_33744_row6_col0" class="data row6 col0" >0.012658</td>
#       <td id="T_33744_row6_col1" class="data row6 col1" >0.257307</td>
#       <td id="T_33744_row6_col2" class="data row6 col2" >-0.549500</td>
#       <td id="T_33744_row6_col3" class="data row6 col3" >0.096067</td>
#       <td id="T_33744_row6_col4" class="data row6 col4" >0.159651</td>
#       <td id="T_33744_row6_col5" class="data row6 col5" >0.216225</td>
#       <td id="T_33744_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Drop Unnecessary Columns
train.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1, inplace=True)
test.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1, inplace=True)

# %%
# Check Missing Values
train.isna().sum()
test.isna().sum()
# Out:
# Pclass       0
# Sex          0
# Age         86
# SibSp        0
# Parch        0
# Fare         1
# Embarked     0
# dtype: int64

# %%
#Fill Missing Values

train['Embarked'] = train['Embarked'].fillna(train['Embarked'].dropna().mode()[0])
test['Fare'] = test['Fare'].fillna(test['Fare'].dropna().mean())

# %%
#Feature Engineering (Sex & Age)

guess_ages = np.zeros((2,3))
combine = [train, test]

# Convert Sex to numeric
for ds in combine:
    ds['Sex'] = ds['Sex'].map({'female':1, 'male':0}).astype(int)

# Fill missing Age
for ds in combine:
    for i in range(2):
        for j in range(3):
            guess_df = ds[(ds['Sex']==i) & (ds['Pclass']==j+1)]['Age'].dropna()
            age_guess = guess_df.median()
            guess_ages[i,j] = int(age_guess/0.5 + 0.5) * 0.5
    for i in range(2):
        for j in range(3):
            ds.loc[(ds['Age'].isnull()) & (ds['Sex']==i) & (ds['Pclass']==j+1), 'Age'] = guess_ages[i,j]
    ds['Age'] = ds['Age'].astype(int)

# %%
# Cleaned Dataset Preview (Sir’s Format)

train_cleaned = train[['Survived','Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']]
train_cleaned.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare Embarked
# 0         0       3    0   22      1      0   7.2500        S
# 1         1       1    1   38      1      0  71.2833        C
# 2         1       3    1   26      0      0   7.9250        S
# 3         1       1    1   35      1      0  53.1000        S
# 4         0       3    0   35      0      0   8.0500        S

# %%
#Prepare Data for Modeling

X_train = pd.get_dummies(train.drop(['Survived'], axis=1))
X_test = pd.get_dummies(test)
y_train = train['Survived']

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
# Out:
# X_train shape: (891, 9)
# X_test shape: (418, 9)

# %%
#  Function to Print Scores
# ------------------------------
def print_scores(model, X_train, y_train, predictions, cv_splits=10):
    print("Training Accuracy: %.5f" % model.score(X_train, y_train))
    CV_scores = cross_val_score(model, X_train, y_train, cv=cv_splits)
    print("Cross-validation scores:\n", CV_scores)
    print("Minimum CV score: %.3f" % min(CV_scores))
    print("Maximum CV score: %.3f" % max(CV_scores))
    print("Mean CV score: %.5f ± %0.2f" % (CV_scores.mean(), CV_scores.std()*2))

# %%
# 11. Train Random Forest Classifier
# ------------------------------
model = RandomForestClassifier(
    n_estimators=80,
    max_depth=5,
    max_features=8,
    min_samples_split=3,
    random_state=7
)

model.fit(X_train, y_train)
predictions = model.predict(X_test)

# %%
# 12. Evaluate Model
# ------------------------------
print_scores(model, X_train, y_train, predictions)
# Out:
# Training Accuracy: 0.85859
# Cross-validation scores:
#  [0.76666667 0.85393258 0.75280899 0.91011236 0.88764045 0.80898876
#  0.80898876 0.78651685 0.87640449 0.84269663]
# Minimum CV score: 0.753
# Maximum CV score: 0.910
# Mean CV score: 0.82948 ± 0.10
